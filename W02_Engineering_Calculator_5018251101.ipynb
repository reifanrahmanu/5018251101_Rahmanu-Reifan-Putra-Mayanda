# %% [markdown]
# <a href="https://colab.research.google.com/github/reifanrahmanu/5018251101_Rahmanu-Reifan-Putra-Mayanda/blob/main/W02_Engineering_Calculator_5018251101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 2 Assignment
# ## Engineering Unit and Electrical Calculator
# Nama: Rahmanu Reifan Putra Mayanda
# NRP: 5018251101
# Kelas: Pemrograman Komputer

# %% [markdown]
# ## Task 1: Speed Unit Conversion

# %%
speed_kmh = 72.0
speed_ms = speed_kmh / 3.6
print(f"Speed: {speed_ms:.2f} m/s")
# Out:
# Speed: 20.00 m/s

# %% [markdown]
# ## Task 2: Power Unit Conversion

# %%
power_kw = 12.5
power_w = power_kw * 1000
print(f"Power: {power_w:.2f} W")
# Out:
# Power: 12500.00 W

# %% [markdown]
# ## Task 3: Electrical Power and Energy Calculator

# %%
voltage = 24.0
current = 8.5
time = 3.0

power = voltage * current
energy = power * time

print("===== ELECTRICAL CALCULATION =====")
print(f"Voltage     = {voltage:.2f} V")
print(f"Current     = {current:.2f} A")
print(f"Power       = {power:.2f} W")
print(f"Operating Time = {time:.2f} hour")
print(f"Energy      = {energy:.2f} Wh")
# Out:
# ===== ELECTRICAL CALCULATION =====
# Voltage     = 24.00 V
# Current     = 8.50 A
# Power       = 204.00 W
# Operating Time = 3.00 hour
# Energy      = 612.00 Wh

# %% [markdown]
# ## Task 4: Logic & Comparison Operators

# %%
voltage_value = 24.0
current_limit = 10.0

is_safe = current_limit <= 15.0
is_high_voltage = voltage_value > 50.0

print(f"Current is within safe limit (<= 15A): {is_safe}")
print(f"Voltage is high (> 50V): {is_high_voltage}")
# Out:
# Current is within safe limit (<= 15A): True
# Voltage is high (> 50V): False

# %% [markdown]
# ## Task 5: Conditional Statements (if-elif-else)

# %%
engine_load = 75.0  # dalam persen [%]

if engine_load < 50.0:
    status = "Low Load"
elif engine_load <= 80.0:
    status = "Normal Load"
else:
    status = "High Load / Overload"

print(f"Engine Load: {engine_load}%")
print(f"Operating Status: {status}")
# Out:
# Engine Load: 75.0%
# Operating Status: Normal Load

# %% [markdown]
# ## Task 6: Loop Structure (for / while)

# %%
print("Monitoring Engine RPM for 5 seconds:")
for second in range(1, 6):
    rpm = 1000 + (second * 150)
    print(f"Time: {second} s -> Engine RPM: {rpm}")
# Out:
# Monitoring Engine RPM for 5 seconds:
# Time: 1 s -> Engine RPM: 1150
# Time: 2 s -> Engine RPM: 1300
# Time: 3 s -> Engine RPM: 1450
# Time: 4 s -> Engine RPM: 1600
# Time: 5 s -> Engine RPM: 1750

# %% [markdown]
# ## Task 7: Reflection & Conclusion

# %% [markdown]
# - Notebook ini berhasil dibuat untuk menyelesaikan perhitungan dasar teknik perkapalan dan kelistrikan menggunakan Python.
# - Penggunaan variabel, tipe data, operator logika, struktur kondisi (`if-else`), dan perulangan (`for loop`) sangat membantu mengotomatisasi perhitungan teknik.
